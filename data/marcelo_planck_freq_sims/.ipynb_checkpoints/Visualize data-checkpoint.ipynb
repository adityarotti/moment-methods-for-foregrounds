# %%
import healpy as h
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d100=h.read_map("./fullsky_cib-halo_0100GHz.fits") ; d100=h.ud_grade(d100,256)
d143=h.read_map("./fullsky_cib-halo_0143GHz.fits") ; d143=h.ud_grade(d143,256)
d217=h.read_map("./fullsky_cib-halo_0217GHz.fits") ; d217=h.ud_grade(d217,256)
d353=h.read_map("./fullsky_cib-halo_0353GHz.fits") ; d353=h.ud_grade(d353,256)
d545=h.read_map("./fullsky_cib-halo_0545GHz.fits") ; d545=h.ud_grade(d545,256)
d857=h.read_map("./fullsky_cib-halo_0857GHz.fits") ; d857=h.ud_grade(d857,256)
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
d857=h.read_map("./fullsky_cib-halo_0857GHz.fits")
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
figure()
hist(d857[d857<0.3],bins=50)
hist(d545[d545<0.1],bins=50)
hist(d353[d353<0.03],bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([   188.,    605.,   1590.,   3339.,   5990.,   9490.,  13760.,
#          18800.,  24215.,  29835.,  34609.,  38745.,  42125.,  44467.,
#          45605.,  45917.,  45278.,  43996.,  41408.,  38488.,  35598.,
#          32222.,  28875.,  25360.,  22059.,  19238.,  16640.,  13924.,
#          11805.,   9921.,   8323.,   6582.,   5491.,   4423.,   3586.,
#           2887.,   2265.,   1920.,   1467.,   1172.,    913.,    706.,
#            562.,    441.,    353.,    286.,    193.,    150.,    125.,
#             97.]),
#  array([ 0.        ,  0.0005999 ,  0.00119979,  0.00179969,  0.00239959,
#          0.00299948,  0.00359938,  0.00419927,  0.00479917,  0.00539907,
#          0.00599896,  0.00659886,  0.00719876,  0.00779865,  0.00839855,
#          0.00899845,  0.00959834,  0.01019824,  0.01079813,  0.01139803,
#          0.01199793,  0.01259782,  0.01319772,  0.01379762,  0.01439751,
# ...

# %%
cld100=h.alm2cl(h.map2alm(d100,lmax=3*256))
cld143=h.alm2cl(h.map2alm(d143,lmax=3*256))
cld217=h.alm2cl(h.map2alm(d217,lmax=3*256))
cld353=h.alm2cl(h.map2alm(d353,lmax=3*256))
cld545=h.alm2cl(h.map2alm(d545,lmax=3*256))
cld857=h.alm2cl(h.map2alm(d857,lmax=3*256))

# %%
cld857=h.alm2cl(h.map2alm(d857,lmax=3*h.get_nside(d857)))

# %%
figure()
ell=arange(3*h.get_nside(d857)+1)
plot(ell,cld857)
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
ell=arange(3*256+1)
figure()
plot(ell,ell*(ell+1)*cld100)
plot(ell,ell*(ell+1)*cld143)
plot(ell,ell*(ell+1)*cld217)
plot(ell,ell*(ell+1)*cld353)
plot(ell,ell*(ell+1)*cld545)
plot(ell,ell*(ell+1)*cld857)
#semilogy()
#xlim(100,200)
#ylim(0,10)
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []
