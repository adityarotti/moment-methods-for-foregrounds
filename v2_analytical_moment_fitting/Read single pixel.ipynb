# %%
from astropy.io import fits
import healpy as h
from sys import getsizeof
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename="../data/marcelo_planck_freq_sims/fullsky_cib-2lpt_0100GHz.fits"
filename="../data/marcelo_planck_freq_sims/fullsky_cib-halo_0100GHz.fits"

#hdulist=fits.open(filename,memmap=True)
#sim=h.read_map(filename,nest=False,memmap=True,verbose=False)

# %%
timeit(h.read_map(filename,nest=False,memmap=True,verbose=False))
# Out:
# 1 loop, best of 3: 922 ms per loop

# %%
timeit(h.read_map(filename,nest=False,verbose=False))
# Out:
# 1 loop, best of 3: 900 ms per loop

# %%
nonzero(hdulist[1].data[0][0][0:40])
# Out:
# (array([ 2,  3,  7,  8,  9, 10, 14, 16, 17, 18, 19, 20, 21, 22, 24, 27, 28,
#         29, 31, 32, 33, 34, 35, 36, 37, 38]),)

# %%
figure()
plot(hdulist[1].data[10][0][4:40])
plot(sim[4:40],"--")
# Out:
# <img src="data:image/png;base64,..." width="640">
