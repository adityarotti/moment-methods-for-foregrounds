# %%
import healpy as h
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nside_low=2 ; nside_high=8 ; pix=35
ml=zeros(h.nside2npix(nside_low))
mh=zeros(h.nside2npix(nside_high))
ml[pix]=1.

# %%
h.mollview(ml,title="Parent pixel",cbar=False)
savefig("./figures/parent_pixel.pdf")
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
v=h.boundaries(nside_low,pix) ; v=np.swapaxes(v,0,1) 
child_pixels=h.query_polygon(nside_high,v)

for i,pix in enumerate(child_pixels):
    mh[pix]=i+1

# %%
h.mollview(mh,title="Children pixel",cbar=False)
savefig("./figures/children_pixel.pdf")
# Out:
# <img src="data:image/png;base64,..." width="850">
