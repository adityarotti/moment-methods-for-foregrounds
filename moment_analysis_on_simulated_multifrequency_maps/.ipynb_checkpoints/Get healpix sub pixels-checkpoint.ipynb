# %%
import healpy as h
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nside_low=2 ; print h.nside2npix(nside_low)
nside_high=16
lr_map=zeros(h.nside2npix(nside_low),float)
hr_map=zeros(h.nside2npix(nside_high),float)
# Out:
# 48

# %%
hr_map=zeros(h.nside2npix(nside_high),float)
for i in range(h.nside2npix(nside_low)):
    v=h.boundaries(nside_low,i)
    v=np.swapaxes(v,0,1)
    p=h.query_polygon(16,v)
    hr_map[p]=hr_map[p] + i+1

# %%
h.mollview(hr_map)
# Out:
# <img src="data:image/png;base64,..." width="850">
