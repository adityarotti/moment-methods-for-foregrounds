# %%
# %pylab notebook

h=6.62607004e-34 #Plancks constant #m2 kg / s
k=1.38064852e-23 #Boltzmann constant #m2 kg s-2 K-1
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def gram_schmidt(vectors):
    basis = []
    for v in vectors:
        w = v - np.sum( np.dot(v,b)*b  for b in basis )
        #norm=np.linalg.norm(w) ; print norm
        norm=np.sqrt(np.dot(w,w)) #; print norm
        if (norm > 1e-16):  
            basis.append(w/norm)
    return np.array(basis)

# %%
def y1(x):
    return x*exp(x)/(exp(x)-1.)

def y2(x):
    return y1(x)*x*cosh(0.5*x)/sinh(0.5*x)

def y3(x):
    return y1(x)*x*x*(cosh(x)+2)/(cosh(x)-1)

def y4(x):
    return y2(x)*0.5*x*x*(cosh(x)+5)/(sinh(0.5*x)**2.)

def y5(x):
    return y1(x)*(x**4.)*(33.+26*cosh(x)+cosh(2.*x))/(8.*sinh(0.5*x)**4.)

def f_mbb(nu,T,alpha,A,p22,p23,p33,p222,p223,p233,p333):
    x=h*nu*1e9/k/T
    nu0=k*T/h/1e9
    I0=A*(((nu/nu0)**alpha)*(nu**3.))/(exp(x)-1.)
    temp=I0*(1. + 0.5*p22*(log(nu/nu0))**2. + p23*log(nu/nu0)*y1(x)+ 0.5*p33*y2(x))
    temp = temp +  I0*(p222*(log(nu/nu0)**3.)/6. + 0.5*p223*(log(nu/nu0)**2.)*y1(x) + 0.5*p233*log(nu/nu0)*y2(x) + p333*y3(x)/6.)
    return temp

# %%
def fn_v0(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=((nu/nu0)**alpha)*(nu**3.)/(exp(x)-1.)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v1(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*log(nu/nu0)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v2(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*y1(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v3(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**2.)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v4(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*log(nu/nu0)*y1(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v5(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*y2(x)/(nu**sl)
    Inu=Inu/max(Inu)
    return Inu

def fn_v6(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**3.)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v7(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*y1(x)*(log(nu/nu0)**2)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v8(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*y2(x)*log(nu/nu0)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v9(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*y3(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v10(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**4)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v11(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**3)*y1(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v12(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**2)*y2(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v13(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**1.)*y3(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v14(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*y4(x)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v15(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**4.)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

def fn_v16(nu,T,alpha,sl=0):
    x=h*nu*1e9/(k*T)
    nu0=k*T/h/1e9
    Inu=fn_v0(nu,T,alpha,sl=sl)*(log(nu/nu0)**5.)/(nu**sl)
    Inu=Inu/max(abs(Inu))
    return Inu

fn_dir=[fn_v0,fn_v1,fn_v2,fn_v3,fn_v4,fn_v5,fn_v6,fn_v7,fn_v8,fn_v9,fn_v10,fn_v11,fn_v12,fn_v13,fn_v14]#,fn_v15,fn_v16]

# %%
nu=linspace(10.,3000.,200.,float64)
#nu=logspace(log10(10.),log10(3000.),200)
#nu=logspace(log10(10),log10(3000),200)
T=13. ; alpha=2. ; sl=alpha*0.
v=list()
for f in fn_dir:
    v.append(f(nu,T,alpha,sl))

# %%
figure()
for i in range(np.size(fn_dir)):
    plot(nu,v[i],label=str(i))
legend(loc=0,ncol=5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
b=gram_schmidt(v)
b=gram_schmidt(b)
b=gram_schmidt(b)
b=gram_schmidt(b)
b=gram_schmidt(b)

# %%
figure()
for i in range(np.size(fn_dir)):
    plot(nu,abs(b[i]-b1[i]),label=str(i))
    plot(nu,abs(b1[i]-b2[i]),"--",label=str(i))
    #plot(nu,b1[i],label=str(i))
semilogy()
legend(loc=0,ncol=5)
#semilogx()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-3f8884935884> in <module>()
#       1 figure()
#       2 for i in range(np.size(fn_dir)):
# ----> 3     plot(nu,abs(b[i]-b1[i]),label=str(i))
#       4     plot(nu,abs(b1[i]-b2[i]),"--",label=str(i))
#       5     #plot(nu,b1[i],label=str(i))
#
# NameError: name 'b1' is not defined

# %%
cov=zeros((np.size(fn_dir),np.size(fn_dir)),float)
for i in range(np.size(fn_dir)):
    for j in range(np.size(fn_dir)):
        cov[i,j]=dot(b[i],b[j])
        
figure()
imshow(log10(abs(cov)))
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:7: RuntimeWarning: divide by zero encountered in log10

# %%
def mbb(nu,T,A,alpha,nu0=1.):
    x=h*nu*1e9/(k*T)
    Inu=A*((nu/nu0)**alpha)*(nu**3.)/(exp(x)-1.)
    return Inu

def multitemp_mbb_spectra(nu,T1,A1,alpha1,T2,A2,alpha2,nu0=1.):
    Inu=mbb(nu,T1,A1,alpha1,nu0=nu0) + mbb(nu,T2,A2,alpha2,nu0=nu0)
    return Inu

# %%
f=0.34188
T1=9.75 ; A1=f; alpha1=1.63; T2=15.7 ; A2 =(1.-f); alpha2=2.82

Abar=A1+A2
Tbar=Abar/((A1/T1)+(A2/T2))
nu0=k*Tbar/h/1e9
print Abar,Tbar,nu0

Inu=multitemp_mbb_spectra(nu,T1,A1,alpha1,T2,A2,alpha2,nu0=3000.)
# Out:
# 1.0 12.9898662496 270.664805898

# %%
p=zeros(b[:,0].size,float)

for i,bs in enumerate(b):
    p[i]=dot(bs,Inu/(nu**sl))
    
print p
# Out:
# [  3.32225307e+07   1.40041546e+07   7.85106493e+06  -1.98263075e+06
#    9.35306289e+05   4.52785507e+05  -4.06848020e+04  -4.43142386e+04
#    9.50870398e+03   1.85378484e+03   3.70047243e+02  -1.33909026e+02
#   -7.25995255e+01   9.17461132e+00   1.75616342e+01]

# %%
d=zeros((b[:,0].size,np.size(nu)),float)
for i in range(b[:,0].size):
    for j in range(i+1):
        d[i,:]=d[i,:] + p[j]*b[j,:]

# %%
figure()
plot(nu,Inu,"k-",lw=2)
for i in range(b[:,0].size):
    plot(nu,d[i,:])
    
figure()
for i in range(b[:,0].size):
    plot(nu,abs(d[i,:]-Inu)/Inu,label=str(i))
legend(loc=0)
loglog()

figure()
plot(nu,Inu,"k-",lw=2)
for i in range(b[:,0].size):
    plot(nu,abs(d[i,:]-Inu),label=str(i))
legend(loc=0)
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# []

# %%
figure()
plot(nu,Inu)
plot(nu,d[2,:])
# Out:
# <img src="data:image/png;base64,..." width="640">
